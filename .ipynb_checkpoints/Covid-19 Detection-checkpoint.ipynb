# %% [markdown]
# #  Covid Detection using XRay Dataset

# %%
import pandas as pd
import os
import shutil

# %%
print(os.listdir("./Dataset"))
TRAIN_PATH = "./Dataset/Train"
VAL_PATH = "./Dataset/Val"
# Out:
# ['Prediction', 'Train', 'Val']

# %% [markdown]
# # Building architecture

# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.layers import *
from keras.models import *
from keras.preprocessing import image

# %%
model = Sequential()
model.add(Conv2D(32,kernel_size=(3,3),activation="relu",input_shape=(224,224,3)))

model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64,(3,3),activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3),activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(3,3),activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(64,activation="relu"))
model.add(Dropout(0.5))

model.add(Dense(1,activation="sigmoid"))

model.compile(loss=keras.losses.binary_crossentropy,optimizer = "adam",metrics=["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 220, 220, 64)      18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 110, 110, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 110, 110, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 108, 108, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 54, 54, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 52, 52, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 26, 26, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                1179712
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 1,457,537
# Trainable params: 1,457,537
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Data Augmentation

# %%
train_datagen = image.ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True,
)
test_dataset = image.ImageDataGenerator(rescale = 1./255)

# %%
train_generator = train_datagen.flow_from_directory(
    './Dataset/Train',
    target_size = (224,224),
    batch_size = 32,
    class_mode = 'binary'
)
# Out:
# Found 356 images belonging to 2 classes.

# %%
train_generator.class_indices
# Out:
# {'Covid': 0, 'Normal': 1}

# %%
validation_generator = test_dataset.flow_from_directory(
    './Dataset/Val',
    target_size = (224,224),
    batch_size = 32,
    class_mode = 'binary'
)
validation_generator.class_indices
# Out:
# Found 60 images belonging to 2 classes.
# {'Covid': 0, 'Normal': 1}

# %% [markdown]
# # Model Fitting

# %%
hist = model.fit(
    train_generator,
    steps_per_epoch = 8,
    epochs = 100,
    validation_data = validation_generator,
    validation_steps = 2
)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 78s 6s/step - loss: 0.8056 - accuracy: 0.4774 - val_loss: 0.6925 - val_accuracy: 0.5000
# Epoch 2/100
# 8/8 [==============================] - 39s 5s/step - loss: 0.6909 - accuracy: 0.5490 - val_loss: 0.6854 - val_accuracy: 0.5000
# Epoch 3/100
# 8/8 [==============================] - 44s 5s/step - loss: 0.6641 - accuracy: 0.5847 - val_loss: 0.5841 - val_accuracy: 0.9333
# Epoch 4/100
# 8/8 [==============================] - 40s 5s/step - loss: 0.6372 - accuracy: 0.6388 - val_loss: 0.5118 - val_accuracy: 0.9667
# Epoch 5/100
# 8/8 [==============================] - 40s 6s/step - loss: 0.4601 - accuracy: 0.7986 - val_loss: 0.4196 - val_accuracy: 0.9667
# Epoch 6/100
# 8/8 [==============================] - 42s 5s/step - loss: 0.4451 - accuracy: 0.8170 - val_loss: 0.2859 - val_accuracy: 0.9667
# Epoch 7/100
# 8/8 [==============================] - 41s 5s/step - loss: 0.4704 - accuracy: 0.8388 - val_loss: 0.4369 - val_accuracy: 0.9000
# Epoch 8/100
# 8/8 [==============================] - 41s 5s/step - loss: 0.4177 - accuracy: 0.7939 - val_loss: 0.2728 - val_accuracy: 0.9333
# Epoch 9/100
# 8/8 [==============================] - 42s 5s/step - loss: 0.4542 - accuracy: 0.8553 - val_loss: 0.2892 - val_accuracy: 0.9333
# Epoch 10/100
# 8/8 [==============================] - 40s 5s/step - loss: 0.4025 - accuracy: 0.8170 - val_loss: 0.3900 - val_accuracy: 0.9833
# Epoch 11/100
# 8/8 [==============================] - 41s 5s/step - loss: 0.3475 - accuracy: 0.8619 - val_loss: 0.1906 - val_accuracy: 0.9833
# Epoch 12/100
# 8/8 [==============================] - 41s 5s/step - loss: 0.3604 - accuracy: 0.8641 - val_loss: 0.2745 - val_accuracy: 0.8667
# Epoch 13/100
# 8/8 [==============================] - 39s 5s/step - loss: 0.4372 - accuracy: 0.8127 - val_loss: 0.2655 - val_accuracy: 0.9833
# Epoch 14/100
# 8/8 [==============================] - 41s 5s/step - loss: 0.3887 - accuracy: 0.8209 - val_loss: 0.1383 - val_accuracy: 0.9833
# Epoch 15/100
# 8/8 [==============================] - 39s 5s/step - loss: 0.3373 - accuracy: 0.8959 - val_loss: 0.1573 - val_accuracy: 0.9500
# Epoch 16/100
# 8/8 [==============================] - 43s 5s/step - loss: 0.3944 - accuracy: 0.8044 - val_loss: 0.2859 - val_accuracy: 1.0000
# Epoch 17/100
# 8/8 [==============================] - 41s 5s/step - loss: 0
100
# 8/8 [==============================] - 40s 5s/step - loss: 0.2098 - accuracy: 0.9221 - val_loss: 0.0844 - val_accuracy: 0.9833
# Epoch 74/100
# 8/8 [==============================] - 42s 5s/step - loss: 0.3034 - accuracy: 0.8416 - val_loss: 0.1121 - val_accuracy: 1.0000
# Epoch 75/100
# 8/8 [==============================] - 39s 5s/step - loss: 0.2335 - accuracy: 0.9003 - val_loss: 0.1032 - val_accuracy: 0.9833
# Epoch 76/100
# 8/8 [==============================] - 43s 5s/step - loss: 0.2825 - accuracy: 0.9007 - val_loss: 0.1378 - val_accuracy: 1.0000
# Epoch 77/100
# 8/8 [==============================] - 40s 5s/step - loss: 0.2235 - accuracy: 0.8910 - val_loss: 0.1148 - val_accuracy: 1.0000
# Epoch 78/100
# 8/8 [==============================] - 39s 5s/step - loss: 0.2149 - accuracy: 0.9191 - val_loss: 0.1012 - val_accuracy: 1.0000
# Epoch 79/100
# 8/8 [==============================] - 40s 5s/step - loss: 0.1893 - accuracy: 0.9348 - val_loss: 0.0693 - val_accuracy: 1.0000
# Epoch 80/100
# 8/8 [==============================] - 42s 5s/step - loss: 0.2149 - accuracy: 0.9289 - val_loss: 0.0987 - val_accuracy: 1.0000
# Epoch 81/100
# 8/8 [==============================] - 43s 5s/step - loss: 0.2009 - accuracy: 0.9083 - val_loss: 0.1655 - val_accuracy: 0.9833
# Epoch 82/100
# 8/8 [==============================] - 40s 5s/step - loss: 0.2244 - accuracy: 0.9205 - val_loss: 0.0983 - val_accuracy: 0.9833
# Epoch 83/100
# 8/8 [==============================] - 39s 5s/step - loss: 0.2317 - accuracy: 0.8910 - val_loss: 0.1245 - val_accuracy: 0.9500
# Epoch 84/100
# 8/8 [==============================] - 39s 5s/step - loss: 0.2523 - accuracy: 0.9015 - val_loss: 0.1575 - val_accuracy: 0.9000
# Epoch 85/100
# 8/8 [==============================] - 42s 5s/step - loss: 0.1959 - accuracy: 0.9240 - val_loss: 0.1030 - val_accuracy: 0.9667
# Epoch 86/100
# 8/8 [==============================] - 40s 5s/step - loss: 0.2351 - accuracy: 0.9239 - val_loss: 0.1289 - val_accuracy: 0.9500
# Epoch 87/100
# 8/8 [==============================] - 41s 6s/step - loss: 0.1887 - accuracy: 0.9206 - val_loss: 0.1345 - val_accuracy: 0.9667
# Epoch 88/100
# 8/8 [==============================] - 40s 5s/step - loss: 0.2140 - accuracy: 0.9117 - val_loss: 0.1343 - val_accuracy: 0.9833
# Epoch 89/100
# 8/8 [==============================] - 42s 5s/step - loss: 0.1877 - accuracy: 0.9121 - val_loss: 0.1028 - val_accuracy: 0.9833
# Epoch 90/100
# 8/8 [==============================] - 39s 5s/step - loss: 0.1919 - accuracy: 0.9266 - val_loss: 0.1736 - val_accuracy: 0.9000
# Epoch 91/100
# 8/8 [==============================] - 39s 5s/step - loss: 0.2300 - accuracy: 0.9148 - val_loss: 0.1134 - val_accuracy: 0.9667
# Epoch 92/100
# 8/8 [==============================] - 42s 5s/step - loss: 0.3147 - accuracy: 0.8899 - val_loss: 0.1424 - val_accuracy: 0.9333
# Epoch 93/100
# 8/8 [==============================] - 41s 5s/step - loss: 0.2156 - accuracy: 0.9170 - val_loss: 0.1227 - val_accuracy: 1.0000
# Epoch 94/100
# 8/8 [==============================] - 39s 6s/step - loss: 0.2025 - accuracy: 0.9297 - val_loss: 0.0782 - val_accuracy: 0.9833
# Epoch 95/100
# 8/8 [==============================] - 41s 5s/step - loss: 0.2516 - accuracy: 0.9098 - val_loss: 0.1281 - val_accuracy: 0.9667
# Epoch 96/100
# 8/8 [==============================] - 40s 5s/step - loss: 0.1789 - accuracy: 0.9265 - val_loss: 0.0653 - val_accuracy: 0.9833
# Epoch 97/100
# 8/8 [==============================] - 39s 5s/step - loss: 0.2601 - accuracy: 0.8960 - val_loss: 0.0910 - val_accuracy: 0.9833
# Epoch 98/100
# 8/8 [==============================] - 41s 5s/step - loss: 0.2218 - accuracy: 0.9014 - val_loss: 0.1004 - val_accuracy: 0.9667
# Epoch 99/100
# 8/8 [==============================] - 41s 5s/step - loss: 0.1502 - accuracy: 0.9261 - val_loss: 0.0962 - val_accuracy: 0.9833
# Epoch 100/100
# 8/8 [==============================] - 40s 5s/step - loss: 0.2435 - accuracy: 0.8765 - val_loss: 0.1352 - val_accuracy: 0.9500

# %% [markdown]
# # Confusion Matrix

# %%
y_actual = []
y_test = []

for i in os.listdir("./Dataset/Val/Covid"):
  img = image.load_img("./Dataset/Val/Covid/"+i,target_size=(224,224,3))
  img = image.img_to_array(img)
  img = np.expand_dims(img,axis=0)
  p = model.predict_classes(img)
  y_test.append(p[0,0])
  y_actual.append(0)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
y_actual = np.array(y_actual)
y_test = np.array(y_test)

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
class_names = ["Covid-19","Normal"]

cm = confusion_matrix(y_actual,y_test)
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap="plasma"):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
plt.figure()
plot_confusion_matrix(cm, classes=class_names,
                      title='Confusion matrix for Covid-19 Detection',cmap="plasma")
# Out:
# Confusion matrix, without normalization
# [[27  3]
#  [ 0  0]]

# %%
history = hist
print(history.history.keys())

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import numpy as np
# from google.colab.patches import cv2_imshow
import cv2
from keras.preprocessing import image
xtest_image = image.load_img('./Dataset/Prediction/ryct.2020200034.fig5-day7.jpeg', target_size = (224, 224,3))
xtest_image = image.img_to_array(xtest_image)
xtest_image = np.expand_dims(xtest_image, axis = 0)
results = model.predict_classes(xtest_image)
# training_set.class_indices
imggg = cv2.imread('./Dataset/Prediction/ryct.2020200034.fig5-day7.jpeg')
print("This Xray Image is of positive covid-19 patient")
imggg = np.array(imggg)
imggg = cv2.resize(imggg,(400,400))
plt.imshow(imggg)
# cv2_imshow(imggg)
# print(results)
if results[0][0] == 0:
    prediction = 'Positive For Covid-19'
else:
    prediction = 'Negative for Covid-19'
print("Prediction Of Our Model : ",prediction)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# This Xray Image is of positive covid-19 patient
# Prediction Of Our Model :  Positive For Covid-19

# %%
hist.history
# Out:
# {'loss': [0.7665860056877136,
#   0.6898300051689148,
#   0.6409713625907898,
#   0.5989094376564026,
#   0.4554482400417328,
#   0.422370582818985,
#   0.48369091749191284,
#   0.3967982232570648,
#   0.4360279440879822,
#   0.40131738781929016,
#   0.36118951439857483,
#   0.35946571826934814,
#   0.4162193834781647,
#   0.35351186990737915,
#   0.37331095337867737,
#   0.39365509152412415,
#   0.3428965210914612,
#   0.34224459528923035,
#   0.33126628398895264,
#   0.28677576780319214,
#   0.3505525290966034,
#   0.29798653721809387,
#   0.26718804240226746,
#   0.2923201322555542,
#   0.2956705689430237,
#   0.33401185274124146,
#   0.4038811922073364,
#   0.3447936177253723,
#   0.2990315854549408,
#   0.3323746621608734,
#   0.3243629038333893,
#   0.262860506772995,
#   0.2979488968849182,
#   0.2802048623561859,
#   0.29057687520980835,
#   0.2542303204536438,
#   0.2917992174625397,
#   0.25271502137184143,
#   0.26145726442337036,
#   0.26333749294281006,
#   0.26148149371147156,
#   0.24084505438804626,
#   0.2742025554180145,
#   0.2578664720058441,
#   0.23648701608181,
#   0.22312889993190765,
#   0.26128044724464417,
#   0.23494085669517517,
#   0.25040265917778015,
#   0.3023853003978729,
#   0.2438354343175888,
#   0.251681387424469,
#   0.25092560052871704,
#   0.2358933389186859,
#   0.24354733526706696,
#   0.22021903097629547,
#   0.2395038604736328,
#   0.2757139801979065,
#   0.24502649903297424,
#   0.2211121916770935,
#   0.23213404417037964,
#   0.2308790534734726,
#   0.20804700255393982,
